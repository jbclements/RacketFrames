# %%
(require RacketFrames)
# Out:
# '#hash((|a	1	| . (0)) (|b	2	| . (1)) (|c	3	| . (2)))
# '#hash((|a	1	| . (0)) (|a	4	| . (3)) (|b	2	| . (1)) (|c	3	| . (2 4)))
# '("2099" "-" "12" "-" "31")
# (Datetime (Date 2099 12 31) (Time 0 0 0 0 0))
# '("2099" "-" "12" "-" "31" "T" "23" "59" "59" "123")
# (Datetime (Date 2099 12 31) (Time 0 23 59 59 123))
# col1	col2	col3
# 1	5	9
# 2	6	10
# 3	7	11
# 4	8	12
# trim-right
# "hello world"
# read-quoted-field
# "hello world"
# "ello world"
# read-unquoted-field
# "hello world  "
# "hello world  "
# "hello world"
# "   hello world  "
#      first           last             age           dollar           phone         join_date
# Evan            Lloyd                        19 $3839.78        (771) 255-1133  (Datetime (Date 2018 5 19) (Time 0 0 0 0 0))
# Etta            Griffith                     50 $8158.60        (523) 731-6388  (Datetime (Date 2018 5 19) (Time 0 0 0 0 0))
# ...

# %%
(make-data-frame)
# Out:
# (data-frame #<semaphore> #f '#hash() '#hash() '#hash())
